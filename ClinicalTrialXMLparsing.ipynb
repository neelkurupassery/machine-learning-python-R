# %%
# Very unoptimized initial exploration
import xml.sax

# %%
xml.sax.make_parser()

# %%
xml.sax.parse(xmlfile,contenthandler[,errorhandler])
# Out:
#   Input In [3]
#     xml.sax.parse(xmlfile,contenthandler[,errorhandler])
#                                          ^
# SyntaxError: invalid syntax

# %%
# import OS module
import os

# Get the list of all files and directories
path = "C://Users//neelk//Desktop//CTD"
dir_list = os.listdir(path)

print("Files and directories in '", path, "' :")

# prints all files
print(dir_list)
# Out:
# Files and directories in ' C://Users//neelk//Desktop//CTD ' :
# ['Contents.txt', 'NCT0000xxxx', 'NCT0001xxxx', 'NCT0002xxxx', 'NCT0003xxxx', 'NCT0004xxxx', 'NCT0005xxxx', 'NCT0006xxxx', 'NCT0007xxxx', 'NCT0008xxxx', 'NCT0009xxxx', 'NCT0010xxxx', 'NCT0011xxxx', 'NCT0012xxxx', 'NCT0013xxxx', 'NCT0014xxxx', 'NCT0015xxxx', 'NCT0016xxxx', 'NCT0017xxxx', 'NCT0018xxxx', 'NCT0019xxxx', 'NCT0020xxxx', 'NCT0021xxxx', 'NCT0022xxxx', 'NCT0023xxxx', 'NCT0024xxxx', 'NCT0025xxxx', 'NCT0026xxxx', 'NCT0027xxxx', 'NCT0028xxxx', 'NCT0029xxxx', 'NCT0030xxxx', 'NCT0031xxxx', 'NCT0032xxxx', 'NCT0033xxxx', 'NCT0034xxxx', 'NCT0035xxxx', 'NCT0036xxxx', 'NCT0037xxxx', 'NCT0038xxxx', 'NCT0039xxxx', 'NCT0040xxxx', 'NCT0041xxxx', 'NCT0042xxxx', 'NCT0043xxxx', 'NCT0044xxxx', 'NCT0045xxxx', 'NCT0046xxxx', 'NCT0047xxxx', 'NCT0048xxxx', 'NCT0049xxxx', 'NCT0050xxxx', 'NCT0051xxxx', 'NCT0052xxxx', 'NCT0053xxxx', 'NCT0054xxxx', 'NCT0055xxxx', 'NCT0056xxxx', 'NCT0057xxxx', 'NCT0058xxxx', 'NCT0059xxxx', 'NCT0060xxxx', 'NCT0061xxxx', 'NCT0062xxxx', 'NCT0063xxxx', 'NCT0064xxxx', 'NCT0065xxxx', 'NCT0066xxxx', 'NCT0067xxxx', 'NCT0068xxxx', 'NCT0069xxxx', 'NCT0070xxxx', 'NCT0071xxxx', 'NCT0072xxxx', 'NCT0073xxxx', 'NCT0074xxxx', 'NCT0075xxxx', 'NCT0076xxxx', 'NCT0077xxxx', 'NCT0078xxxx', 'NCT0079xxxx', 'NCT0080xxxx', 'NCT0081xxxx', 'NCT0082xxxx', 'NCT0083xxxx', 'NCT0084xxxx', 'NCT0085xxxx', 'NCT0086xxxx', 'NCT0087xxxx', 'NCT0088xxxx', 'NCT0089xxxx', 'NCT0090xxxx', 'NCT0091xxxx', 'NCT0092xxxx', 'NCT0093xxxx', 'NCT0094xxxx', 'NCT0095xxxx', 'NCT0096xxxx', 'NCT0097xxxx', 'NCT0098xxxx', 'NCT0099xxxx', 'NCT0100xxxx', 'NCT0101xxxx', 'NCT0102xxxx', 'NCT0103xxxx', 'NCT0104xxxx', 'NCT0105xxxx', 'NCT0106xxxx', 'NCT0107xxxx', 'NCT0108xxxx', 'NCT0109xxxx', 'NCT0110xxxx', 'NCT0111xxxx', 'NCT0112xxxx', 'NCT0113xxxx', 'NCT0114xxxx', 'NCT0115xxxx', 'NCT0116xxxx', 'NCT0117xxxx', 'NCT0118xxxx', 'NCT0119xxxx', 'NCT0120xxxx', 'NCT0121xxxx', 'NCT0122xxxx', 'NCT0123xxxx', 'NCT0124xxxx', 'NCT0125xxxx', 'NCT0126xxxx', 'NCT0127xxxx', 'NCT0128xxxx', 'NCT0129xxxx', 'NCT0130xxxx', 'NCT0131xxxx', 'NCT0132xxxx', 'NCT0133xxxx', 'NCT0134xxxx', 'NCT0135xxxx', 'NCT0136xxxx', 'NCT0137xxxx', 'NCT0138xxxx', 'NCT0139xxxx', 'NCT0140xxxx', 'NCT0141xxxx', 'NCT0142xxxx', 'NCT0143xxxx', 'NCT0144xxxx', 'NCT0145xxxx', 'NCT0146xxxx', 'NCT0147xxxx', 'NCT0148xxxx', 'NCT0149xxxx', 'NCT0150xxxx', 'NCT0151xxxx', 'NCT0152xxxx', 'NCT0153xxxx', 'NCT0154xxxx', 'NCT0155xxxx', 'NCT0156xxxx', 'NCT0157xxxx', 'NCT0158xxxx', 'NCT0159xxxx', 'NCT0160xxxx', 'NCT0161xxxx', 'NCT0162xxxx', 'NCT0163xxxx', 'NCT0164xxxx', 'NCT0165xxxx', 'NCT0166xxxx', 'NCT0167xxxx', 'NCT0168xxxx', 'NCT0169xxxx', 'NCT0170xxxx', 'NCT0171xxxx', 'NCT0172xxxx', 'NCT0173xxxx', 'NCT0174xxxx', 'NCT0175xxxx', 'NCT0176xxxx', 'NCT0177xxxx', 'NCT0178xxxx', 'NCT0179xxxx', 'NCT0180xxxx', 'NCT0181xxxx', 'NCT0182xxxx', 'NCT0183xxxx', 'NCT0184xxxx', 'NCT0185xxxx', 'NCT0186xxxx', 'NCT0187xxxx', 'NCT0188xxxx', 'NCT0189xxxx', 'NCT0190xxxx', 'NCT0191xxxx', 'NCT0192xxxx', 'NCT0193xxxx', 'NCT0194xxxx', 'NCT0195xxxx', 'NCT0196xxxx', 'NCT0197xxxx', 'NCT0198xxxx', 'NCT0199xxxx', 'NCT0200xxxx', 'NCT0201xxxx', 'NCT0202xxxx', 'NCT0203xxxx', 'NCT0204xxxx', 'NCT0205xxxx', 'NCT0206xxxx', 'NCT0207xxxx', 'NCT0208xxxx', 'NCT0209xxxx', 'NCT0210xxxx', 'NCT0211xxxx', 'NCT0212xxxx', 'NCT0213xxxx', 'NCT0214xxxx', 'NCT0215xxxx', 'NCT0216xxxx', 'NCT0217xxxx', 'NCT0218xxxx', 'NCT0219xxxx', 'NCT0220xxxx', 'NCT0221xxxx', 'NCT0222xxxx', 'NCT0223xxxx', 'NCT0224xxxx', 'NCT0225xxxx', 'NCT0226xxxx', 'NCT0227xxxx', 'NCT0228xxxx', 'NCT0229xxxx', 'NCT0230xxxx', 'NCT0231xxxx', 'NCT0232xxxx', 'NCT0233xxxx', 'NCT0234xxxx', 'NCT0235xxxx', 'NCT0236xxxx', 'NCT0237xxxx', 'NCT0238xxxx', 'NCT0239xxxx', 'NCT0240xxxx', 'NCT0241xxxx', 'NCT0242xxxx', 'NCT0243xxxx', 'NCT0244xxxx', 'NCT0245xxxx', 'NCT0246xxxx', 'NCT0247xxxx', 'NCT0248xxxx', 'NCT0249xxxx', 'NCT0250xxxx', 'NCT0251xxxx', 'NCT0252xxxx', 'NCT0253xxxx', 'NCT0254xxxx', 'NCT0255xxxx', 'NCT0256xxxx', 'NCT0257xxxx', 'NCT0258xxxx', 'NCT0259xxxx', 'NCT0260xxxx', 'NCT0261xxxx', 'NCT0262xxxx', 'NCT0263xxxx', 'NCT0264xxxx', 'NCT0265 ...

# %%
dir_list2 = os.listdir(path + "//" + dir_list[1])
firstXMLpath = path + "//" + dir_list[1] + "//" + dir_list2[1]
print(firstXMLpath)
# Out:
# C://Users//neelk//Desktop//CTD//NCT0000xxxx//NCT00000104.xml

# %%
import json
import xmltodict

# %%
pip install xmltodict
# Out:
# Collecting xmltodict
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.13.0
# Note: you may need to restart the kernel to use updated packages.

# %%
json.loads(json_data)['clinical_study']['study_type']
# Out:
# 'Observational'

# %%
import json
import xmltodict
import numpy as np
import pandas as pd
study_type_full = []
path = "C://Users//neelk//Desktop//CTD"
dir_list = os.listdir(path)
for i in (range(len(dir_list))):
    print(str(i+1) + " out of " + str(len(dir_list)), end = "\r")
    dir_list2 = os.listdir(path + "//" + dir_list[i])
    for j in range(len(dir_list2)):
        pXMLpath = path + "//" + dir_list[i] + "//" + dir_list2[j]
        with open(pXMLpath, encoding='utf-8') as xml_file:
            data_dict = xmltodict.parse(xml_file.read())
            json_data = json.dumps(data_dict)
            study_type_full = np.append(study_type_full, json.loads(json_data)['clinical_study']['study_type'])
# Out:
# 12 out of 567
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [65], in <cell line: 8>()
#      14 data_dict = xmltodict.parse(xml_file.read())
#      15 json_data = json.dumps(data_dict)
# ---> 16 study_type_full = np.append(study_type_full, json.loads(json_data)['clinical_study']['study_type'])
#
# File <__array_function__ internals>:5, in append(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\function_base.py:4817, in append(arr, values, axis)
#    4815     values = ravel(values)
#    4816     axis = arr.ndim-1
# -> 4817 return concatenate((arr, values), axis=axis)
#
# File <__array_function__ internals>:5, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
pd.value_counts(np.array(study_type_full))
# Out:
# Interventional                      36449
# Observational                        6471
# Expanded Access                        41
# Observational [Patient Registry]       24
# N/A                                     3
# dtype: int64

# %%
i
# Out:
# 6

# %%
j
# Out:
# 224

# %%
json_data
# Out:
# '{"clinical_study": {"required_header": {"download_date": "ClinicalTrials.gov processed this data on December 22, 2022", "link_text": "Link to the current ClinicalTrials.gov record.", "url": "https://clinicaltrials.gov/show/NCT00063219"}, "id_info": {"org_study_id": "3128K1-201", "nct_id": "NCT00063219"}, "brief_title": "Study Evaluating MAC-321 in Non-small Cell Lung Cancer Refractory to Platinum-based Therapy", "official_title": "A Phase 2, Open-label Study of MAC-321 Administered Intravenously as a Single Agent for the Treatment of Non-small Cell Lung Cancer Refractory to Platinum-based Therapy", "sponsors": {"lead_sponsor": {"agency": "Wyeth is now a wholly owned subsidiary of Pfizer", "agency_class": "Industry"}}, "source": "Wyeth is now a wholly owned subsidiary of Pfizer", "brief_summary": {"textblock": "This non-randomized, open-label clinical trial is designed to determine safety and clinical\\r\\n      activity of a new chemotherapeutic agent, MAC-321, when given intravenously to patients with\\r\\n      non-small cell lung cancer. Clinical activity will be evaluated by determining the percentage\\r\\n      of patients with an objective tumor response after treatment with MAC-321. Patients must have\\r\\n      been previously treated with a platinum-containing chemotherapy regimen.\\r\\n\\r\\n      A total of 96 patients will be enrolled in this trial. Eligible patients will receive MAC-321\\r\\n      intravenously every 3 weeks for up to a total of 6 courses of treatment. All patients will\\r\\n      receive MAC-321 at the same dose. MAC-321 is an experimental drug, and is not offered outside\\r\\n      of this research trial."}, "overall_status": "Completed", "completion_date": {"@type": "Actual", "#text": "February 2005"}, "primary_completion_date": {"@type": "Actual", "#text": "February 2005"}, "phase": "Phase 2", "study_type": "Interventional", "study_design_info": {"allocation": "Non-Randomized", "primary_purpose": "Treatment", "masking": "None (Open Label)"}, "enrollment": {"@type": "Actual", "#text": "48"}, "condition": ["Carcinoma, Non-Small-Cell Lung", "Lung Neoplasms"], "intervention": {"intervention_type": "Drug", "intervention_name": "MAC-321"}, "eligibility": {"criteria": {"textblock": "Inclusion Criteria:\\r\\n\\r\\n          -  Recurrence of non-small cell lung cancer after at least 1 prior chemotherapy regimen\\r\\n             containing a platinum agent\\r\\n\\r\\n          -  Recovery from all acute side effects of prior therapies (with the exception of hair\\r\\n             loss)\\r\\n\\r\\n          -  Adequate bone marrow, liver, and kidney function\\r\\n\\r\\n        Exclusion Criteria:\\r\\n\\r\\n          -  More than 2 prior chemotherapy regimens for treatment of advanced or metastatic\\r\\n             non-small cell lung cancer. (Treatment given in conjunction with surgery will not be\\r\\n             included in the maximum of 2 prior regimens)\\r\\n\\r\\n          -  Radiation therapy, chemotherapy or any other anticancer therapy within 28 days of\\r\\n             beginning study\\r\\n\\r\\n          -  Symptomatic brain metastases"}, "gender": "All", "minimum_age": "18 Years", "maximum_age": "N/A", "healthy_volunteers": "No"}, "overall_official": {"last_name": "Medical Monitor, MD", "role": "Study Director", "affiliation": "Wyeth is now a wholly owned subsidiary of Pfizer"}, "location": [{"facility": {"address": {"city": "Los Angeles", "state": "California", "zip": "90033", "country": "United States"}}}, {"facility": {"address": {"city": "Lexington", "state": "Kentucky", "zip": "40536-0098", "country": "United States"}}}, {"facility": {"address": {"city": "Baltimore", "state": "Maryland", "zip": "21231-1000", "country": "United States"}}}, {"facility": {"address": {"city": "Worcester", "state": "Massachusetts", "zip": "01655", "country": "United States"}}}, {"facility": {"address": {"city": "Minneapolis", "state": "Minnesota", "zip": "55455", "country": "United States"}}}, {"facilit ...

# %%
 b'\x81'.decode('Latin1') 
 b'\x81'.decode('Latin2') 
 b'\x81'.decode('iso8859') 
 b'\x81'.decode('iso8859-2')
# Out:
# '\x81'

# %%
with open(pXMLpath, encoding='utf-8') as xml_file:
            data_dict = xmltodict.parse(xml_file.read())

# %%
json_data
# Out:
# '{"clinical_study": {"required_header": {"download_date": "ClinicalTrials.gov processed this data on December 22, 2022", "link_text": "Link to the current ClinicalTrials.gov record.", "url": "https://clinicaltrials.gov/show/NCT00117598"}, "id_info": {"org_study_id": "3066K1-305", "nct_id": "NCT00117598", "nct_alias": "NCT00326547"}, "brief_title": "Study Evaluating Temsirolimus (CCI-779) In Mantle Cell Lymphoma (MCL)", "acronym": "OPTIMAL", "official_title": "An Open-Label, Randomized, Phase 3 Trial Of Intravenous Temsirolimus (CCI-779) At Two Dose Levels Compared To Investigator\'s Choice Therapy In Relapsed, Refractory Subjects With Mantle Cell Lymphoma (MCL)", "sponsors": {"lead_sponsor": {"agency": "Pfizer", "agency_class": "Industry"}}, "source": "Pfizer", "oversight_info": {"has_dmc": "Yes"}, "brief_summary": {"textblock": "This is an open-label, randomized trial in relapsed refractory subjects with mantle cell\\r\\n      lymphoma (MCL)."}, "overall_status": "Completed", "start_date": "May 2005", "completion_date": {"@type": "Actual", "#text": "January 2011"}, "primary_completion_date": {"@type": "Actual", "#text": "August 2007"}, "phase": "Phase 3", "study_type": "Interventional", "has_expanded_access": "No", "study_design_info": {"allocation": "Randomized", "intervention_model": "Parallel Assignment", "primary_purpose": "Treatment", "masking": "None (Open Label)"}, "primary_outcome": {"measure": "Progression-Free Survival (PFS)", "time_frame": "Baseline, every 8 weeks up to Year 1, then every 12 weeks up to Year 2, and then every 6 months until tumor progression or death (up to Year 5)", "description": "The period from randomization until disease progression, death or date of last contact."}, "secondary_outcome": {"measure": "Percentage of Participants With Objective Response", "time_frame": "Baseline, every 8 weeks up to Year 1, then every 12 weeks up to Year 2, and then every 6 months until tumor progression or death (up to Year 5)", "description": "Assessment of complete or partial response (CR, PR) or uncomplete response (CRu) using Response Evaluation Criteria in Solid Tumors. CR: 1) No disease evident. 2) Lymph node, nodal mass regressed to normal size. 3) Previously enlarged organ \\u2193 size. 4) Bone marrow clear on repeat aspirate, biopsy. CRu: CR 1 and 3, at least 1 of following: Lymph node regressed >75%. Bone marrow \\u2191 number or aggregate size, no cytologic/architectural atypia. PR: \\u226550% \\u2193 index lesion, no size \\u2191 in other nodes, liver, spleen. Splenic and hepatic nodule regressed \\u226550%. No new disease."}, "other_outcome": [{"measure": "Overall Survival (OS)", "time_frame": "Baseline up to 5 years", "description": "Overall survival is the duration from randomization to death. For participants who are alive, overall survival is censored at the last contact."}, {"measure": "Time to Response", "time_frame": "Baseline, every 8 weeks up to Year 1, then every 12 weeks up to Year 2, and then every 6 months until tumor progression or death (up to Year 5)", "description": "Time between the date of randomization and the first date of objective response for participants with a confirmed objective response."}, {"measure": "Duration of Response", "time_frame": "Baseline, every 8 weeks up to Year 1, then every 12 weeks up to Year 2, and then every 6 months until tumor progression or death (up to Year 5)", "description": "Time from the first documentation of objective tumor response to first date that recurrence or progressive disease (PD) was objectively documented; censored at last valid tumor assessment."}, {"measure": "Time to Failure (TTF)", "time_frame": "Baseline, every 8 weeks up to Year 1, then every 12 weeks up to Year 2, and then every 6 months until tumor progression or death (up to Year 5)", "description": "TTF is defined as the time from randomization to the date of the first documentation of Progressive Disease (PD), the date of treatment discontinuation except completion of trea ...

# %%
json.loads(json_data)['clinical_study']
# Out:
# {'required_header': {'download_date': 'ClinicalTrials.gov processed this data on December 22, 2022',
#   'link_text': 'Link to the current ClinicalTrials.gov record.',
#   'url': 'https://clinicaltrials.gov/show/NCT00117598'},
#  'id_info': {'org_study_id': '3066K1-305',
#   'nct_id': 'NCT00117598',
#   'nct_alias': 'NCT00326547'},
#  'brief_title': 'Study Evaluating Temsirolimus (CCI-779) In Mantle Cell Lymphoma (MCL)',
#  'acronym': 'OPTIMAL',
#  'official_title': "An Open-Label, Randomized, Phase 3 Trial Of Intravenous Temsirolimus (CCI-779) At Two Dose Levels Compared To Investigator's Choice Therapy In Relapsed, Refractory Subjects With Mantle Cell Lymphoma (MCL)",
#  'sponsors': {'lead_sponsor': {'agency': 'Pfizer',
#    'agency_class': 'Industry'}},
#  'source': 'Pfizer',
#  'oversight_info': {'has_dmc': 'Yes'},
#  'brief_summary': {'textblock': 'This is an open-label, randomized trial in relapsed refractory subjects with mantle cell\r\n      lymphoma (MCL).'},
#  'overall_status': 'Completed',
#  'start_date': 'May 2005',
#  'completion_date': {'@type': 'Actual', '#text': 'January 2011'},
#  'primary_completion_date': {'@type': 'Actual', '#text': 'August 2007'},
#  'phase': 'Phase 3',
#  'study_type': 'Interventional',
#  'has_expanded_access': 'No',
#  'study_design_info': {'allocation': 'Randomized',
#   'intervention_model': 'Parallel Assignment',
#   'primary_purpose': 'Treatment',
#   'masking': 'None (Open Label)'},
#  'primary_outcome': {'measure': 'Progression-Free Survival (PFS)',
#   'time_frame': 'Baseline, every 8 weeks up to Year 1, then every 12 weeks up to Year 2, and then every 6 months until tumor progression or death (up to Year 5)',
#   'description': 'The period from randomization until disease progression, death or date of last contact.'},
#  'secondary_outcome': {'measure': 'Percentage of Participants With Objective Response',
#   'time_frame': 'Baseline, every 8 weeks up to Year 1, then every 12 weeks up to Year 2, and then every 6 months until tumor progression or death (up to Year 5)',
#   'description': 'Assessment of complete or partial response (CR, PR) or uncomplete response (CRu) using Response Evaluation Criteria in Solid Tumors. CR: 1) No disease evident. 2) Lymph node, nodal mass regressed to normal size. 3) Previously enlarged organ ↓ size. 4) Bone marrow clear on repeat aspirate, biopsy. CRu: CR 1 and 3, at least 1 of following: Lymph node regressed >75%. Bone marrow ↑ number or aggregate size, no cytologic/architectural atypia. PR: ≥50% ↓ index lesion, no size ↑ in other nodes, liver, spleen. Splenic and hepatic nodule regressed ≥50%. No new disease.'},
#  'other_outcome': [{'measure': 'Overall Survival (OS)',
#    'time_frame': 'Baseline up to 5 years',
#    'description': 'Overall survival is the duration from randomization to death. For participants who are alive, overall survival is censored at the last contact.'},
#   {'measure': 'Time to Response',
#    'time_frame': 'Baseline, every 8 weeks up to Year 1, then every 12 weeks up to Year 2, and then every 6 months until tumor progression or death (up to Year 5)',
#    'description': 'Time between the date of randomization and the first date of objective response for participants with a confirmed objective response.'},
#   {'measure': 'Duration of Response',
#    'time_frame': 'Baseline, every 8 weeks up to Year 1, then every 12 weeks up to Year 2, and then every 6 months until tumor progression or death (up to Year 5)',
#    'description': 'Time from the first documentation of objective tumor response to first date that recurrence or progressive disease (PD) was objectively documented; censored at last valid tumor assessment.'},
#   {'measure': 'Time to Failure (TTF)',
#    'time_frame': 'Baseline, every 8 weeks up to Year 1, then every 12 weeks up to Year 2, and then every 6 months until tumor progression or death (up to Year 5)',
#    'description': 'TTF is defined as the time from randomization to the date of the first documentation of Progressive Disease (PD), the date of treatment discontinuation except completion of treatment, or date of death (any cause).'},
#   {'measure': 'Time to Tumor Progression (TTP)',
#    'time_frame': 'Baseline, every 8 weeks up to Year 1, then every 12 weeks up to Year 2, and then every 6 months until tumor progression or death (up to Year 5)',
#    'description': 'TTP: time from randomization to first documentation of objective tumor progression (including recurrence); censored at last valid tumor assessment.'}],
#  'number_of_arms': '3',
#  'enrollment': {'@type': 'Actual', '#text': '169'},
#  'condition': 'Lymphoma',
#  'arm_group': [{'arm_group_label': 'A', 'arm_group_type': 'Experimental'},
#   {'arm_group_label': 'B', 'arm_group_type': 'Experimental'},
#   {'arm_group_label': 'C', 'arm_group_type': 'Active Comparator'}],
#  'intervention': [{'intervention_type': 'Drug',
#    'intervention_name': 'Temsirolimus (CCI-779)',
#    'description': 'Temsirolimus 175 mg IV once a week for 3 weeks; followed by 75 mg IV once a week',
#    'arm_group_label': 'A'},
#   {'intervention_type': 'Drug',
#    'intervention_name': 'Temsirolimus (CCI-779)',
#    'description': 'Temsirolimus 175 mg IV once a week for 3 weeks; followed by 25 mg IV once a week',
#    'arm_group_label': 'B'},
#   {'intervention_type': 'Drug',
#    'intervention_name': "Investigator's choice",
#    'description': 'Any of the following single agent treatments:\r\nFludarabine 25 mg/m2 IV over 30 minutes daily for 5 consecutive days, every 28 days or oral administration, as appropriate.\r\nChlorambucil 0.1 (0.1-0.2) mg/kg PO daily for 3 to 6 weeks as required OR 0.4 (0.3 0.8) mg/kg PO every 21 to 28 days\r\nGemcitabine 1 gm/m2 IV over 30 minutes on days 1, 8 and 15 every 28 days or day 1 and day 8 every 21 days\r\nCyclophosphamide 300 (200-450) mg/m2 PO daily for 5 consecutive days every 21 to 28 days, OR 600 (400-1200) mg/m2 IV every 21 to 28 days\r\nCladribine 5 mg/m2 IV daily for 5 consecutive days, every 28 days for 2-6 cycles depending on response,\r\nEtoposide 50 (50-150) mg/m2 IV daily for 3-5 days every 21 to 28 days OR 100 (50 300) mg/m2 PO daily for 3-5 days every 21 to 28 days\r\nPrednisone 40 (20-60) mg/m2 PO daily or every other day\r\nDexamethasone 20(20-40) mg PO/IV daily for 5 consecutive days, every 14 - 28 day',
#    'arm_group_label': 'C'}],
#  'eligibility': {'criteria': {'textblock': 'Inclusion Criteria:\r\n\r\n          -  Mantle cell lymphoma (MCL) confirmed with histology, immunophenotype, and cyclin D1\r\n             analysis\r\n\r\n          -  Received 2 to 7 prior therapies which may include hematopoietic stem cell transplant\r\n             (i.e. induction + consolidation + maintenance)\r\n\r\n          -  Prior treatment with an alkylating agent and an anthracycline, rituximab, individually\r\n             or in combination, and status that is at least one of the following:\r\n\r\n          -  Primary disease refractory to at least 2 regimens;\r\n\r\n          -  Refractory to at least 1 regimen after first relapse;\r\n\r\n          -  Refractory or untreated after second or greater relapse;\r\n\r\n          -  Refractory to first line and relapsed after second line. Chemotherapy combinations may\r\n             include, but are not limited to: CHOP (Cyclophosphamide, doxorubicin, vincristine,\r\n             prednisone), R-CHOP (Rituximab, Cyclophosphamide, doxorubicin, vincristine,\r\n             prednisone), FCM (Fludarabine, cyclophosphamide, mitoxantrone), R-FCM\r\n             (Rituximab,Fludarabine, cyclophosphamide, mitoxantrone), ICE(Ifosfamide, carboplatin,\r\n             etoposide), DHAP (Dexamethasone, cisplatin, cytarabine) and hyper-CVAD\r\n             (Cyclophosphamide, doxorubicin, vincristine, dexamethasone).\r\n\r\n        Exclusion Criteria:\r\n\r\n          -  Subjects who are less than or equal to six month from allogeneic hematopoietic stem\r\n             cell transplant and who are on immunosuppressive therapy or have evidence of graft\r\n             versus host disease\r\n\r\n          -  Prior investigational therapy within 3 weeks of first dose. Investigational therapy is\r\n             defined as treatment that is not approved for any indication.\r\n\r\n          -  Active central nervous system (CNS) metastases, as indicated by clinical symptoms,\r\n             cerebral edema, requirement for corticosteroids and/or progressive growth. (Treated\r\n             CNS metastases must be stable for > 2 weeks prior to Day 1.)'},
#   'gender': 'All',
#   'minimum_age': '18 Years',
#   'maximum_age': 'N/A',
#   'healthy_volunteers': 'No'},
#  'overall_official': {'last_name': 'Pfizer CT.gov Call Center',
#   'role': 'Study Director',
#   'affiliation': 'Pfizer'},
#  'location': [{'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Little Rock',
#      'state': 'Arkansas',
#      'zip': '72205',
#      'country': 'United States'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Fountain Valley',
#      'state': 'California',
#      'zip': '92708',
#      'country': 'United States'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Los Angeles',
#      'state': 'California',
#      'zip': '90024-2828',
#      'country': 'United States'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'New Milford',
#      'state': 'Connecticut',
#      'zip': '06776',
#      'country': 'United States'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Washington',
#      'state': 'District of Columbia',
#      'zip': '20007',
#      'country': 'United States'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Boca Raton',
#      'state': 'Florida',
#      'zip': '33428',
#      'country': 'United States'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Honolulu',
#      'state': 'Hawaii',
#      'zip': '96813',
#      'country': 'United States'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Chicago',
#      'state': 'Illinois',
#      'zip': '60612',
#      'country': 'United States'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Morristown',
#      'state': 'New Jersey',
#      'zip': '07960',
#      'country': 'United States'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Buffalo',
#      'state': 'New York',
#      'zip': '14263',
#      'country': 'United States'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'New York',
#      'state': 'New York',
#      'zip': '10029-6574',
#      'country': 'United States'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Rochester',
#      'state': 'New York',
#      'zip': '14642-8668',
#      'country': 'United States'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Portland',
#      'state': 'Oregon',
#      'zip': '97227',
#      'country': 'United States'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Upland',
#      'state': 'Pennsylvania',
#      'zip': '19013',
#      'country': 'United States'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Austin',
#      'state': 'Texas',
#      'zip': '78705',
#      'country': 'United States'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Grapevine',
#      'state': 'Texas',
#      'zip': '76051',
#      'country': 'United States'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Houston',
#      'state': 'Texas',
#      'zip': '77030-4009',
#      'country': 'United States'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Temple',
#      'state': 'Texas',
#      'zip': '76508',
#      'country': 'United States'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Seattle',
#      'state': 'Washington',
#      'zip': '98101',
#      'country': 'United States'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Buenos Aires',
#      'zip': 'C1405BWU',
#      'country': 'Argentina'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Buenos Aires',
#      'zip': 'C1406FWZ',
#      'country': 'Argentina'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Cordoba', 'zip': '5000', 'country': 'Argentina'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'East Melbourne',
#      'state': 'Victoria',
#      'zip': '3000',
#      'country': 'Australia'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Wien', 'zip': 'A-1090', 'country': 'Austria'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Brugge', 'zip': '8000', 'country': 'Belgium'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Gent', 'zip': '9000', 'country': 'Belgium'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Leuven', 'zip': '3000', 'country': 'Belgium'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Vila Buarque',
#      'state': 'Sao Paulo',
#      'zip': '01221-010',
#      'country': 'Brazil'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Porto Alegre - RS',
#      'zip': '90610-000',
#      'country': 'Brazil'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Edmonton',
#      'state': 'Alberta',
#      'zip': 'T6G 1Z2',
#      'country': 'Canada'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Vancouver',
#      'state': 'British Columbia',
#      'zip': 'V6Z 1Y6',
#      'country': 'Canada'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'London',
#      'state': 'Ontario',
#      'zip': 'N6A 4L5',
#      'country': 'Canada'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Ottawa',
#      'state': 'Ontario',
#      'zip': 'K1H 8L6',
#      'country': 'Canada'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Toronto',
#      'state': 'Ontario',
#      'zip': 'M5G 2C4',
#      'country': 'Canada'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Greenfield Park',
#      'state': 'Quebec',
#      'zip': 'J4V 2H1',
#      'country': 'Canada'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Montreal',
#      'state': 'Quebec',
#      'zip': 'H1T2M4',
#      'country': 'Canada'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Montreal',
#      'state': 'Quebec',
#      'zip': 'H4J 1C5',
#      'country': 'Canada'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Providencia',
#      'state': 'Santiago',
#      'country': 'Chile'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Beijing', 'zip': '100021', 'country': 'China'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Beijing', 'zip': '100036', 'country': 'China'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Shanghai', 'zip': '2000025', 'country': 'China'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Shanghai', 'zip': '200032', 'country': 'China'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Shanghai', 'zip': '200433', 'country': 'China'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Lyon', 'zip': '69008', 'country': 'France'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Paris Cedex 15',
#      'zip': '75747',
#      'country': 'France'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Paris', 'zip': '75475', 'country': 'France'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Pierre Benite',
#      'zip': '69495',
#      'country': 'France'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Strasbourg', 'zip': '67098', 'country': 'France'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Villejuif Cedex',
#      'zip': '94805',
#      'country': 'France'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Ulm',
#      'state': 'BW',
#      'zip': '89070',
#      'country': 'Germany'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Ulm',
#      'state': 'BW',
#      'zip': '89081',
#      'country': 'Germany'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Heidelberg', 'zip': '69120', 'country': 'Germany'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Mainz', 'zip': '55131', 'country': 'Germany'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Bologna', 'zip': '40128', 'country': 'Italy'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Catania', 'zip': '95124', 'country': 'Italy'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Milano', 'zip': '20132', 'country': 'Italy'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Roma', 'zip': '00161', 'country': 'Italy'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Rotterdam',
#      'zip': '3015 GD',
#      'country': 'Netherlands'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Lublin', 'zip': '20-081', 'country': 'Poland'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Warszawa', 'zip': '02-781', 'country': 'Poland'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': "L'Hospitalet de Llobregat",
#      'state': 'Barcelona',
#      'zip': '08907',
#      'country': 'Spain'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Pamplona',
#      'state': 'Navarra',
#      'zip': '31008',
#      'country': 'Spain'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Barcelona', 'zip': '08035', 'country': 'Spain'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Madrid', 'zip': '28006', 'country': 'Spain'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Madrid', 'zip': '28041', 'country': 'Spain'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Lund', 'zip': '221 85', 'country': 'Sweden'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Uppsala', 'zip': '751 85', 'country': 'Sweden'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Aarau', 'zip': '5001', 'country': 'Switzerland'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Plymouth',
#      'state': 'Devon',
#      'zip': 'PL6 8DH',
#      'country': 'United Kingdom'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Southampton',
#      'state': 'Hants',
#      'zip': 'SO16 6YD',
#      'country': 'United Kingdom'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Tooting',
#      'state': 'London',
#      'zip': 'SW17 0QT',
#      'country': 'United Kingdom'}}},
#   {'facility': {'name': 'Pfizer Investigational Site',
#     'address': {'city': 'Sutton',
#      'state': 'Surrey',
#      'zip': 'SM2 5PT',
#      'country': 'United Kingdom'}}}],
#  'location_countries': {'country': ['Argentina',
#    'Australia',
#    'Austria',
#    'Belgium',
#    'Brazil',
#    'Canada',
#    'Chile',
#    'China',
#    'France',
#    'Germany',
#    'Italy',
#    'Netherlands',
#    'Poland',
#    'Spain',
#    'Sweden',
#    'Switzerland',
#    'United Kingdom',
#    'United States']},
#  'link': {'url': 'https://trialinfoemail.pfizer.com/pages/landing.aspx?StudyID=3066K1-305&StudyName=Study%20Evaluating%20Temsirolimus%20%28CCI-779%29%20In%20Mantle%20Cell%20Lymphoma%20%28MCL%29',
#   'description': 'To obtain contact information for a study center near you, click here.'},
#  'verification_date': 'March 2015',
#  'study_first_submitted': 'June 30, 2005',
#  'study_first_submitted_qc': 'June 30, 2005',
#  'study_first_posted': {'@type': 'Estimate', '#text': 'July 7, 2005'},
#  'results_first_submitted': 'February 2, 2012',
#  'results_first_submitted_qc': 'February 2, 2012',
#  'results_first_posted': {'@type': 'Estimate', '#text': 'March 6, 2012'},
#  'disposition_first_submitted': 'December 1, 2011',
#  'disposition_first_submitted_qc': 'December 1, 2011',
#  'disposition_first_posted': {'@type': 'Estimate',
#   '#text': 'December 8, 2011'},
#  'last_update_submitted': 'March 10, 2015',
#  'last_update_submitted_qc': 'March 10, 2015',
#  'last_update_posted': {'@type': 'Estimate', '#text': 'March 30, 2015'},
#  'responsible_party': {'responsible_party_type': 'Sponsor'},
#  'keyword': 'Lymphoma',
#  'condition_browse': {'mesh_term': ['Lymphoma', 'Lymphoma, Mantle-Cell']},
#  'intervention_browse': {'mesh_term': 'Sirolimus'},
#  'clinical_results': {'participant_flow': {'pre_assignment_details': 'September 5, 2007: Sponsor conducted primary analysis of progression free survival. As a result of these preliminary data, participants receiving investigator choice therapy and those receiving 175/25 mg temsirolimus could cross over to receive treatment with 175/75 mg temsirolimus (Protocol Amendment 5).',
#    'group_list': {'group': [{'@group_id': 'P1',
#       'title': 'Temsirolimus 175/75 mg',
#       'description': 'Temsirolimus 175 milligrams (mg) administered intravenously (IV) once weekly for 3 weeks then 75 mg temsirolimus IV once weekly until disease progression or treatment withdrawal.'},
#      {'@group_id': 'P2',
#       'title': 'Temsirolimus 175/25 mg',
#       'description': 'Temsirolimus 175 mg IV once weekly for 3 weeks then 25 mg temsirolimus IV once weekly until disease progression or treatment withdrawal.'},
#      {'@group_id': 'P3',
#       'title': "Investigator's Choice",
#       'description': 'Participants received 1 single-agent treatment, chosen by investigator:\r\nFludarabine 25 milligram per meter squared (mg/m^2) IV daily for 5 consecutive days, every 28 days or oral administration, as needed;\r\nChlorambucil 0.1 (0.1-0.2) mg per kilogram, orally (mg/kg, PO) daily for 3 to 6 weeks as required or 0.4 (0.3-0.8) mg/kg PO every 21 to 28 days;\r\nGemcitabine 1 g/m^2 IV on Days 1, 8, and 15, every 28 days or Days 1 and 8 every 21 days;\r\nCyclophosphamide 300 (200-450) mg/m^2 PO daily for 5 consecutive days every 21 to 28 days, or 600 (400-1200) mg/m^2 IV every 21 to 28 days;\r\nCladribine 5 mg/m^2 IV daily for 5 consecutive days every 28 days for 2-6 cycles;\r\nEtoposide 50 (50-150) mg/m^2 IV daily for 3-5 days every 21 to 28 days or 100 (50-300) mg/m^2 PO daily for 3-5 days every 21 to 28 days;\r\nPrednisone 40 (20-60) mg/m^2 PO daily or every other day;\r\nDexamethasone 20 (20-40) mg PO/IV daily for 5 consecutive days every 14 to 28 days.'},
#      {'@group_id': 'P4',
#       'title': 'Temsirolimus 175/25 mg Then 75 mg',
#       'description': 'Temsirolimus 175 mg administered IV once weekly for 3 weeks then 25 mg temsirolimus IV once weekly until treatment cross over allowed (via Protocol Amendment 5), then 75 mg temsirolimus IV once weekly until disease progression or treatment withdrawal.'},
#      {'@group_id': 'P5',
#       'title': "Investigator's Choice Then Temsirolimus 175/75 mg",
#       'description': 'Participants received 1 single-agent treatment chosen by investigator until treatment cross over allowed (via Protocol Amendment 5), then temsirolimus 175 mg IV once weekly for 3 weeks; then 75 mg temsirolimus IV once weekly until disease progression or treatment withdrawal.'}]},
#    'period_list': {'period': [{'title': 'Prior to Treatment Cross Over',
#       'milestone_list': {'milestone': [{'title': 'STARTED',
#          'participants_list': {'participants': [{'@group_id': 'P1',
#             '@count': '57'},
#            {'@group_id': 'P2', '@count': '56'},
#            {'@group_id': 'P3', '@count': '56'},
#            {'@group_id': 'P4', '@count': '0'},
#            {'@group_id': 'P5', '@count': '0'}]}},
#         {'title': 'COMPLETED',
#          'participants_list': {'participants': [{'@group_id': 'P1',
#             '@count': '0'},
#            {'@group_id': 'P2', '@count': '3'},
#            {'@group_id': 'P3', '@count': '4'},
#            {'@group_id': 'P4', '@count': '0'},
#            {'@group_id': 'P5', '@count': '0'}]}},
#         {'title': 'NOT COMPLETED',
#          'participants_list': {'participants': [{'@group_id': 'P1',
#             '@count': '57'},
#            {'@group_id': 'P2', '@count': '53'},
#            {'@group_id': 'P3', '@count': '52'},
#            {'@group_id': 'P4', '@count': '0'},
#            {'@group_id': 'P5', '@count': '0'}]}}]},
#       'drop_withdraw_reason_list': {'drop_withdraw_reason': [{'title': 'Death',
#          'participants_list': {'participants': [{'@group_id': 'P1',
#             '@count': '40'},
#            {'@group_id': 'P2', '@count': '41'},
#            {'@group_id': 'P3', '@count': '37'},
#            {'@group_id': 'P4', '@count': '0'},
#            {'@group_id': 'P5', '@count': '0'}]}},
#         {'title': 'Lost to Follow-up',
#          'participants_list': {'participants': [{'@group_id': 'P1',
#             '@count': '0'},
#            {'@group_id': 'P2', '@count': '2'},
#            {'@group_id': 'P3', '@count': '2'},
#            {'@group_id': 'P4', '@count': '0'},
#            {'@group_id': 'P5', '@count': '0'}]}},
#         {'title': 'Withdrawal by Subject',
#          'participants_list': {'participants': [{'@group_id': 'P1',
#             '@count': '2'},
#            {'@group_id': 'P2', '@count': '1'},
#            {'@group_id': 'P3', '@count': '4'},
#            {'@group_id': 'P4', '@count': '0'},
#            {'@group_id': 'P5', '@count': '0'}]}},
#         {'title': 'Other',
#          'participants_list': {'participants': [{'@group_id': 'P1',
#             '@count': '15'},
#            {'@group_id': 'P2', '@count': '9'},
#            {'@group_id': 'P3', '@count': '9'},
#            {'@group_id': 'P4', '@count': '0'},
#            {'@group_id': 'P5', '@count': '0'}]}}]}},
#      {'title': 'After Treament Cross Over',
#       'milestone_list': {'milestone': [{'title': 'STARTED',
#          'participants_list': {'participants': [{'@group_id': 'P1',
#             '@count': '0'},
#            {'@group_id': 'P2', '@count': '0'},
#            {'@group_id': 'P3', '@count': '0'},
#            {'@group_id': 'P4', '@count': '3'},
#            {'@group_id': 'P5', '@count': '4'}]}},
#         {'title': 'COMPLETED',
#          'participants_list': {'participants': [{'@group_id': 'P1',
#             '@count': '0'},
#            {'@group_id': 'P2', '@count': '0'},
#            {'@group_id': 'P3', '@count': '0'},
#            {'@group_id': 'P4', '@count': '0'},
#            {'@group_id': 'P5', '@count': '0'}]}},
#         {'title': 'NOT COMPLETED',
#          'participants_list': {'participants': [{'@group_id': 'P1',
#             '@count': '0'},
#            {'@group_id': 'P2', '@count': '0'},
#            {'@group_id': 'P3', '@count': '0'},
#            {'@group_id': 'P4', '@count': '3'},
#            {'@group_id': 'P5', '@count': '4'}]}}]},
#       'drop_withdraw_reason_list': {'drop_withdraw_reason': [{'title': 'Death',
#          'participants_list': {'participants': [{'@group_id': 'P1',
#             '@count': '0'},
#            {'@group_id': 'P2', '@count': '0'},
#            {'@group_id': 'P3', '@count': '0'},
#            {'@group_id': 'P4', '@count': '1'},
#            {'@group_id': 'P5', '@count': '2'}]}},
#         {'title': 'Withdrawal by Subject',
#          'participants_list': {'participants': [{'@group_id': 'P1',
#             '@count': '0'},
#            {'@group_id': 'P2', '@count': '0'},
#            {'@group_id': 'P3', '@count': '0'},
#            {'@group_id': 'P4', '@count': '1'},
#            {'@group_id': 'P5', '@count': '0'}]}},
#         {'title': 'Other',
#          'participants_list': {'participants': [{'@group_id': 'P1',
#             '@count': '0'},
#            {'@group_id': 'P2', '@count': '0'},
#            {'@group_id': 'P3', '@count': '0'},
#            {'@group_id': 'P4', '@count': '1'},
#            {'@group_id': 'P5', '@count': '2'}]}}]}}]}},
#   'baseline': {'group_list': {'group': [{'@group_id': 'B1',
#       'title': 'Temsirolimus 175/75 mg',
#       'description': 'Temsirolimus 175 milligrams (mg) administered intravenously (IV) once weekly for 3 weeks then 75 mg temsirolimus IV once weekly until disease progression or treatment withdrawal.'},
#      {'@group_id': 'B2',
#       'title': 'Temsirolimus 175/25 mg',
#       'description': 'Temsirolimus 175 mg IV once weekly for 3 weeks then 25 mg temsirolimus IV once weekly until disease progression or treatment withdrawal.'},
#      {'@group_id': 'B3',
#       'title': "Investigator's Choice",
#       'description': 'Participants received 1 single-agent treatment, chosen by investigator:\r\nFludarabine 25 milligram per meter squared (mg/m^2) IV daily for 5 consecutive days, every 28 days or oral administration, as needed;\r\nChlorambucil 0.1 (0.1-0.2) mg per kilogram, orally (mg/kg, PO) daily for 3 to 6 weeks as required or 0.4 (0.3-0.8) mg/kg PO every 21 to 28 days;\r\nGemcitabine 1 g/m^2 IV on Days 1, 8, and 15, every 28 days or Days 1 and 8 every 21 days;\r\nCyclophosphamide 300 (200-450) mg/m^2 PO daily for 5 consecutive days every 21 to 28 days, or 600 (400-1200) mg/m^2 IV every 21 to 28 days;\r\nCladribine 5 mg/m^2 IV daily for 5 consecutive days every 28 days for 2-6 cycles;\r\nEtoposide 50 (50-150) mg/m^2 IV daily for 3-5 days every 21 to 28 days or 100 (50-300) mg/m^2 PO daily for 3-5 days every 21 to 28 days;\r\nPrednisone 40 (20-60) mg/m^2 PO daily or every other day;\r\nDexamethasone 20 (20-40) mg PO/IV daily for 5 consecutive days every 14 to 28 days.'},
#      {'@group_id': 'B4',
#       'title': 'Total',
#       'description': 'Total of all reporting groups'}]},
#    'analyzed_list': {'analyzed': {'units': 'Participants',
#      'scope': 'Overall',
#      'count_list': {'count': [{'@group_id': 'B1', '@value': '57'},
#        {'@group_id': 'B2', '@value': '56'},
#        {'@group_id': 'B3', '@value': '56'},
#        {'@group_id': 'B4', '@value': '169'}]}}},
#    'measure_list': {'measure': [{'title': 'Age, Customized',
#       'units': 'years',
#       'param': 'Number',
#       'class_list': {'class': [{'title': '<65 years',
#          'category_list': {'category': {'measurement_list': {'measurement': [{'@group_id': 'B1',
#               '@value': '24'},
#              {'@group_id': 'B2', '@value': '17'},
#              {'@group_id': 'B3', '@value': '28'},
#              {'@group_id': 'B4', '@value': '69'}]}}}},
#         {'title': '>=65 years',
#          'category_list': {'category': {'measurement_list': {'measurement': [{'@group_id': 'B1',
#               '@value': '33'},
#              {'@group_id': 'B2', '@value': '39'},
#              {'@group_id': 'B3', '@value': '28'},
#              {'@group_id': 'B4', '@value': '100'}]}}}}]}},
#      {'title': 'Sex: Female, Male',
#       'units': 'Participants',
#       'param': 'Count of Participants',
#       'class_list': {'class': {'category_list': {'category': [{'title': 'Female',
#            'measurement_list': {'measurement': [{'@group_id': 'B1',
#               '@value': '9'},
#              {'@group_id': 'B2', '@value': '15'},
#              {'@group_id': 'B3', '@value': '8'},
#              {'@group_id': 'B4', '@value': '32'}]}},
#           {'title': 'Male',
#            'measurement_list': {'measurement': [{'@group_id': 'B1',
#               '@value': '48'},
#              {'@group_id': 'B2', '@value': '41'},
#              {'@group_id': 'B3', '@value': '48'},
#              {'@group_id': 'B4', '@value': '137'}]}}]}}}}]}},
#   'outcome_list': {'outcome': [{'type': 'Primary',
#      'title': 'Progression-Free Survival (PFS)',
#      'description': 'The period from randomization until disease progression, death or date of last contact.',
#      'time_frame': 'Baseline, every 8 weeks up to Year 1, then every 12 weeks up to Year 2, and then every 6 months until tumor progression or death (up to Year 5)',
#      'population': 'Intent-to-Treat (ITT) Population: All randomized participants at time of primary analysis',
#      'group_list': {'group': [{'@group_id': 'O1',
#         'title': 'Temsirolimus 175/75 mg',
#         'description': 'Temsirolimus 175 milligrams (mg) administered intravenously (IV) once weekly for 3 weeks then 75 mg temsirolimus IV once weekly until disease progression or treatment withdrawal.'},
#        {'@group_id': 'O2',
#         'title': 'Temsirolimus 175/25 mg',
#         'description': 'Temsirolimus 175 mg IV once weekly for 3 weeks then 25 mg temsirolimus IV once weekly until disease progression or treatment withdrawal.'},
#        {'@group_id': 'O3',
#         'title': "Investigator's Choice",
#         'description': 'Participants received 1 single-agent treatment, chosen by investigator:\r\nFludarabine 25 milligram per meter squared (mg/m^2) IV daily for 5 consecutive days, every 28 days or oral administration, as needed;\r\nChlorambucil 0.1 (0.1-0.2) mg per kilogram, orally (mg/kg, PO) daily for 3 to 6 weeks as required or 0.4 (0.3-0.8) mg/kg PO every 21 to 28 days;\r\nGemcitabine 1 g/m^2 IV on Days 1, 8, and 15, every 28 days or Days 1 and 8 every 21 days;\r\nCyclophosphamide 300 (200-450) mg/m^2 PO daily for 5 consecutive days every 21 to 28 days, or 600 (400-1200) mg/m^2 IV every 21 to 28 days;\r\nCladribine 5 mg/m^2 IV daily for 5 consecutive days every 28 days for 2-6 cycles;\r\nEtoposide 50 (50-150) mg/m^2 IV daily for 3-5 days every 21 to 28 days or 100 (50-300) mg/m^2 PO daily for 3-5 days every 21 to 28 days;\r\nPrednisone 40 (20-60) mg/m^2 PO daily or every other day;\r\nDexamethasone 20 (20-40) mg PO/IV daily for 5 consecutive days every 14 to 28 days.'}]},
#      'measure': {'title': 'Progression-Free Survival (PFS)',
#       'description': 'The period from randomization until disease progression, death or date of last contact.',
#       'population': 'Intent-to-Treat (ITT) Population: All randomized participants at time of primary analysis',
#       'units': 'months',
#       'param': 'Median',
#       'dispersion': '95% Confidence Interval',
#       'analyzed_list': {'analyzed': {'units': 'Participants',
#         'scope': 'Measure',
#         'count_list': {'count': [{'@group_id': 'O1', '@value': '54'},
#           {'@group_id': 'O2', '@value': '54'},
#           {'@group_id': 'O3', '@value': '54'}]}}},
#       'class_list': {'class': {'category_list': {'category': {'measurement_list': {'measurement': [{'@group_id': 'O1',
#              '@value': '4.8',
#              '@lower_limit': '2.9',
#              '@upper_limit': '7.0'},
#             {'@group_id': 'O2',
#              '@value': '3.7',
#              '@lower_limit': '3.4',
#              '@upper_limit': '6.2'},
#             {'@group_id': 'O3',
#              '@value': '1.8',
#              '@lower_limit': '1.6',
#              '@upper_limit': '2.0'}]}}}}}},
#      'analysis_list': {'analysis': [{'group_id_list': {'group_id': ['O1',
#           'O3']},
#         'groups_desc': "Two null hypotheses (Ho) tested: 1. PFS distributions for temsirolimus 175/75 mg and investigator's choice treatment groups are identical. 2. PFS distributions for temsirolimus 175/25 mg and investigator's choice treatment groups are identical. Alternative hypothesis (Ha) for each test was that PFS distributions differed.",
#         'non_inferiority_type': 'Superiority or Other',
#         'p_value': '<0.0001',
#         'method': 'Log Rank',
#         'param_type': 'Hazard Ratio (HR)',
#         'param_value': '0.39',
#         'ci_percent': '95',
#         'ci_n_sides': '2-Sided',
#         'ci_lower_limit': '0.25',
#         'ci_upper_limit': '0.63',
#         'estimate_desc': 'HR from a cox model adjusted for baseline stratification factors'},
#        {'group_id_list': {'group_id': ['O2', 'O3']},
#         'non_inferiority_type': 'Superiority or Other',
#         'p_value': '<0.0001',
#         'method': 'Log Rank',
#         'param_type': 'Hazard Ratio (HR)',
#         'param_value': '0.41',
#         'ci_percent': '95',
#         'ci_n_sides': '2-Sided',
#         'ci_lower_limit': '0.26',
#         'ci_upper_limit': '0.65',
#         'estimate_desc': 'HR from a cox model adjusted for baseline stratification factors'}]}},
#     {'type': 'Secondary',
#      'title': 'Percentage of Participants With Objective Response',
#      'description': 'Assessment of complete or partial response (CR, PR) or uncomplete response (CRu) using Response Evaluation Criteria in Solid Tumors. CR: 1) No disease evident. 2) Lymph node, nodal mass regressed to normal size. 3) Previously enlarged organ ↓ size. 4) Bone marrow clear on repeat aspirate, biopsy. CRu: CR 1 and 3, at least 1 of following: Lymph node regressed >75%. Bone marrow ↑ number or aggregate size, no cytologic/architectural atypia. PR: ≥50% ↓ index lesion, no size ↑ in other nodes, liver, spleen. Splenic and hepatic nodule regressed ≥50%. No new disease.',
#      'time_frame': 'Baseline, every 8 weeks up to Year 1, then every 12 weeks up to Year 2, and then every 6 months until tumor progression or death (up to Year 5)',
#      'population': 'ITT',
#      'group_list': {'group': [{'@group_id': 'O1',
#         'title': 'Temsirolimus 175/75 mg',
#         'description': 'Temsirolimus 175 milligrams (mg) administered intravenously (IV) once weekly for 3 weeks then 75 mg temsirolimus IV once weekly until disease progression or treatment withdrawal.'},
#        {'@group_id': 'O2',
#         'title': 'Temsirolimus 175/25 mg',
#         'description': 'Temsirolimus 175 mg IV once weekly for 3 weeks then 25 mg temsirolimus IV once weekly until disease progression or treatment withdrawal.'},
#        {'@group_id': 'O3',
#         'title': "Investigator's Choice",
#         'description': 'Participants received 1 single-agent treatment, chosen by investigator:\r\nFludarabine 25 milligram per meter squared (mg/m^2) IV daily for 5 consecutive days, every 28 days or oral administration, as needed;\r\nChlorambucil 0.1 (0.1-0.2) mg per kilogram, orally (mg/kg, PO) daily for 3 to 6 weeks as required or 0.4 (0.3-0.8) mg/kg PO every 21 to 28 days;\r\nGemcitabine 1 g/m^2 IV on Days 1, 8, and 15, every 28 days or Days 1 and 8 every 21 days;\r\nCyclophosphamide 300 (200-450) mg/m^2 PO daily for 5 consecutive days every 21 to 28 days, or 600 (400-1200) mg/m^2 IV every 21 to 28 days;\r\nCladribine 5 mg/m^2 IV daily for 5 consecutive days every 28 days for 2-6 cycles;\r\nEtoposide 50 (50-150) mg/m^2 IV daily for 3-5 days every 21 to 28 days or 100 (50-300) mg/m^2 PO daily for 3-5 days every 21 to 28 days;\r\nPrednisone 40 (20-60) mg/m^2 PO daily or every other day;\r\nDexamethasone 20 (20-40) mg PO/IV daily for 5 consecutive days every 14 to 28 days.'}]},
#      'measure': {'title': 'Percentage of Participants With Objective Response',
#       'description': 'Assessment of complete or partial response (CR, PR) or uncomplete response (CRu) using Response Evaluation Criteria in Solid Tumors. CR: 1) No disease evident. 2) Lymph node, nodal mass regressed to normal size. 3) Previously enlarged organ ↓ size. 4) Bone marrow clear on repeat aspirate, biopsy. CRu: CR 1 and 3, at least 1 of following: Lymph node regressed >75%. Bone marrow ↑ number or aggregate size, no cytologic/architectural atypia. PR: ≥50% ↓ index lesion, no size ↑ in other nodes, liver, spleen. Splenic and hepatic nodule regressed ≥50%. No new disease.',
#       'population': 'ITT',
#       'units': 'percentage of participants',
#       'param': 'Number',
#       'dispersion': '95% Confidence Interval',
#       'analyzed_list': {'analyzed': {'units': 'Participants',
#         'scope': 'Measure',
#         'count_list': {'count': [{'@group_id': 'O1', '@value': '54'},
#           {'@group_id': 'O2', '@value': '54'},
#           {'@group_id': 'O3', '@value': '54'}]}}},
#       'class_list': {'class': {'category_list': {'category': {'measurement_list': {'measurement': [{'@group_id': 'O1',
#              '@value': '22.2',
#              '@lower_limit': '11.1',
#              '@upper_limit': '33.3'},
#             {'@group_id': 'O2',
#              '@value': '5.6',
#              '@lower_limit': '0.0',
#              '@upper_limit': '11.7'},
#             {'@group_id': 'O3',
#              '@value': '1.9',
#              '@lower_limit': '0.0',
#              '@upper_limit': '5.4'}]}}}}}},
#      'analysis_list': {'analysis': [{'group_id_list': {'group_id': ['O1',
#           'O3']},
#         'non_inferiority_type': 'Superiority or Other',
#         'p_value': '0.0019',
#         'method': 'Fisher Exact'},
#        {'group_id_list': {'group_id': ['O2', 'O3']},
#         'non_inferiority_type': 'Superiority or Other',
#         'p_value': '0.6179',
#         'method': 'Fisher Exact'}]}},
#     {'type': 'Other Pre-specified',
#      'title': 'Overall Survival (OS)',
#      'description': 'Overall survival is the duration from randomization to death. For participants who are alive, overall survival is censored at the last contact.',
#      'time_frame': 'Baseline up to 5 years',
#      'population': 'ITT',
#      'group_list': {'group': [{'@group_id': 'O1',
#         'title': 'Temsirolimus 175/75 mg',
#         'description': 'Temsirolimus 175 milligrams (mg) administered intravenously (IV) once weekly for 3 weeks then 75 mg temsirolimus IV once weekly until disease progression or treatment withdrawal.'},
#        {'@group_id': 'O2',
#         'title': 'Temsirolimus 175/25 mg',
#         'description': 'Temsirolimus 175 mg IV once weekly for 3 weeks then 25 mg temsirolimus IV once weekly until disease progression or treatment withdrawal.'},
#        {'@group_id': 'O3',
#         'title': "Investigator's Choice",
#         'description': 'Participants received 1 single-agent treatment, chosen by investigator:\r\nFludarabine 25 milligram per meter squared (mg/m^2) IV daily for 5 consecutive days, every 28 days or oral administration, as needed;\r\nChlorambucil 0.1 (0.1-0.2) mg per kilogram, orally (mg/kg, PO) daily for 3 to 6 weeks as required or 0.4 (0.3-0.8) mg/kg PO every 21 to 28 days;\r\nGemcitabine 1 g/m^2 IV on Days 1, 8, and 15, every 28 days or Days 1 and 8 every 21 days;\r\nCyclophosphamide 300 (200-450) mg/m^2 PO daily for 5 consecutive days every 21 to 28 days, or 600 (400-1200) mg/m^2 IV every 21 to 28 days;\r\nCladribine 5 mg/m^2 IV daily for 5 consecutive days every 28 days for 2-6 cycles;\r\nEtoposide 50 (50-150) mg/m^2 IV daily for 3-5 days every 21 to 28 days or 100 (50-300) mg/m^2 PO daily for 3-5 days every 21 to 28 days;\r\nPrednisone 40 (20-60) mg/m^2 PO daily or every other day;\r\nDexamethasone 20 (20-40) mg PO/IV daily for 5 consecutive days every 14 to 28 days.'}]},
#      'measure': {'title': 'Overall Survival (OS)',
#       'description': 'Overall survival is the duration from randomization to death. For participants who are alive, overall survival is censored at the last contact.',
#       'population': 'ITT',
#       'units': 'months',
#       'param': 'Median',
#       'dispersion': '95% Confidence Interval',
#       'analyzed_list': {'analyzed': {'units': 'Participants',
#         'scope': 'Measure',
#         'count_list': {'count': [{'@group_id': 'O1', '@value': '54'},
#           {'@group_id': 'O2', '@value': '54'},
#           {'@group_id': 'O3', '@value': '54'}]}}},
#       'class_list': {'class': {'category_list': {'category': {'measurement_list': {'measurement': [{'@group_id': 'O1',
#              '@value': '11.1',
#              '@lower_limit': '8.2',
#              '@upper_limit': '18.0'},
#             {'@group_id': 'O2',
#              '@value': '8.8',
#              '@lower_limit': '6.4',
#              '@upper_limit': '14.5'},
#             {'@group_id': 'O3',
#              '@value': '9.5',
#              '@lower_limit': '5.3',
#              '@upper_limit': '15.1'}]}}}}}},
#      'analysis_list': {'analysis': [{'group_id_list': {'group_id': ['O1',
#           'O3']},
#         'non_inferiority_type': 'Superiority or Other',
#         'p_value': '0.3053',
#         'method': 'Log Rank',
#         'param_type': 'Hazard Ratio (HR)',
#         'param_value': '0.77',
#         'ci_percent': '95',
#         'ci_n_sides': '2-Sided',
#         'ci_lower_limit': '0.46',
#         'ci_upper_limit': '1.28',
#         'estimate_desc': 'HR from a cox model adjusted for baseline stratification factors'},
#        {'group_id_list': {'group_id': ['O2', 'O3']},
#         'non_inferiority_type': 'Superiority or Other',
#         'p_value': '0.9515',
#         'method': 'Log Rank',
#         'param_type': 'Cox Proportional Hazard',
#         'param_value': '0.98',
#         'ci_percent': '95',
#         'ci_n_sides': '2-Sided',
#         'ci_lower_limit': '0.60',
#         'ci_upper_limit': '1.62',
#         'estimate_desc': 'HR from a cox model adjusted for baseline stratification factors'}]}},
#     {'type': 'Other Pre-specified',
#      'title': 'Time to Response',
#      'description': 'Time between the date of randomization and the first date of objective response for participants with a confirmed objective response.',
#      'time_frame': 'Baseline, every 8 weeks up to Year 1, then every 12 weeks up to Year 2, and then every 6 months until tumor progression or death (up to Year 5)',
#      'population': 'ITT subset of participants with a confirmed objective response',
#      'group_list': {'group': [{'@group_id': 'O1',
#         'title': 'Temsirolimus 175/75 mg',
#         'description': 'Temsirolimus 175 milligrams (mg) administered intravenously (IV) once weekly for 3 weeks then 75 mg temsirolimus IV once weekly until disease progression or treatment withdrawal.'},
#        {'@group_id': 'O2',
#         'title': 'Temsirolimus 175/25 mg',
#         'description': 'Temsirolimus 175 mg IV once weekly for 3 weeks then 25 mg temsirolimus IV once weekly until disease progression or treatment withdrawal.'},
#        {'@group_id': 'O3',
#         'title': "Investigator's Choice",
#         'description': 'Participants received 1 single-agent treatment, chosen by investigator:\r\nFludarabine 25 milligram per meter squared (mg/m^2) IV daily for 5 consecutive days, every 28 days or oral administration, as needed;\r\nChlorambucil 0.1 (0.1-0.2) mg per kilogram, orally (mg/kg, PO) daily for 3 to 6 weeks as required or 0.4 (0.3-0.8) mg/kg PO every 21 to 28 days;\r\nGemcitabine 1 g/m^2 IV on Days 1, 8, and 15, every 28 days or Days 1 and 8 every 21 days;\r\nCyclophosphamide 300 (200-450) mg/m^2 PO daily for 5 consecutive days every 21 to 28 days, or 600 (400-1200) mg/m^2 IV every 21 to 28 days;\r\nCladribine 5 mg/m^2 IV daily for 5 consecutive days every 28 days for 2-6 cycles;\r\nEtoposide 50 (50-150) mg/m^2 IV daily for 3-5 days every 21 to 28 days or 100 (50-300) mg/m^2 PO daily for 3-5 days every 21 to 28 days;\r\nPrednisone 40 (20-60) mg/m^2 PO daily or every other day;\r\nDexamethasone 20 (20-40) mg PO/IV daily for 5 consecutive days every 14 to 28 days.'}]},
#      'measure': {'title': 'Time to Response',
#       'description': 'Time between the date of randomization and the first date of objective response for participants with a confirmed objective response.',
#       'population': 'ITT subset of participants with a confirmed objective response',
#       'units': 'months',
#       'param': 'Median',
#       'dispersion': '95% Confidence Interval',
#       'analyzed_list': {'analyzed': {'units': 'Participants',
#         'scope': 'Measure',
#         'count_list': {'count': [{'@group_id': 'O1', '@value': '12'},
#           {'@group_id': 'O2', '@value': '3'},
#           {'@group_id': 'O3', '@value': '1'}]}}},
#       'class_list': {'class': {'category_list': {'category': {'measurement_list': {'measurement': [{'@group_id': 'O1',
#              '@value': '3.6',
#              '@lower_limit': '3.5',
#              '@upper_limit': '4.0'},
#             {'@group_id': 'O2',
#              '@value': '3.5',
#              '@lower_limit': '3.5',
#              '@upper_limit': '4.1'},
# ...
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '1',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '1',
#             '@subjects_at_risk': '4'}]},
#          {'sub_title': 'Pharyngitis',
#           'counts': [{'@group_id': 'E1',
#             '@subjects_affected': '7',
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '9',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '4',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '4'}]},
#          {'sub_title': 'Pleural Disorder',
#           'counts': [{'@group_id': 'E1',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '1',
#             '@subjects_at_risk': '4'}]},
#          {'sub_title': 'Pleural Effusion',
#           'counts': [{'@group_id': 'E1',
#             '@subjects_affected': '6',
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '3',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '4',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '4'}]},
#          {'sub_title': 'Pneumonia',
#           'counts': [{'@group_id': 'E1',
#             '@subjects_affected': '6',
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '8',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '5',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '1',
#             '@subjects_at_risk': '4'}]},
#          {'sub_title': 'Pulmonary Physical Finding',
#           'counts': [{'@group_id': 'E1',
#             '@subjects_affected': '1',
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '5',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '2',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '4'}]},
#          {'sub_title': 'Rhinitis',
#           'counts': [{'@group_id': 'E1',
#             '@subjects_affected': '6',
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '5',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '3',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '4'}]},
#          {'sub_title': 'Sinusitis',
#           'counts': [{'@group_id': 'E1',
#             '@subjects_affected': '6',
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '2',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '4'}]},
#          {'sub_title': 'Upper Respiratory Infection',
#           'counts': [{'@group_id': 'E1',
#             '@subjects_affected': '9',
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '4',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '2',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '2',
#             '@subjects_at_risk': '4'}]},
#          {'sub_title': 'Voice Alteration',
#           'counts': [{'@group_id': 'E1',
#             '@subjects_affected': '3',
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '1',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '4'}]}]}},
#       {'title': 'Skin and subcutaneous tissue disorders',
#        'event_list': {'event': [{'sub_title': 'Acne',
#           'description': 'Skin And Appendages',
#           'counts': [{'@group_id': 'E1',
#             '@subjects_affected': '5',
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '2',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '4'}]},
#          {'sub_title': 'Dry Skin',
#           'counts': [{'@group_id': 'E1',
#             '@subjects_affected': '7',
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '5',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '1',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '4'}]},
#          {'sub_title': 'Eczema',
#           'counts': [{'@group_id': 'E1',
#             '@subjects_affected': '3',
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '3',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '4'}]},
#          {'sub_title': 'Erythema',
#           'counts': [{'@group_id': 'E1',
#             '@subjects_affected': '6',
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '1',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '2',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '1',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '4'}]},
#          {'sub_title': 'Fungal Dermatitis',
#           'counts': [{'@group_id': 'E1',
#             '@subjects_affected': '1',
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '3',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '1',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '4'}]},
#          {'sub_title': 'Herpes Simplex',
#           'counts': [{'@group_id': 'E1',
#             '@subjects_affected': '6',
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '10',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '4',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '1',
#             '@subjects_at_risk': '4'}]},
#          {'sub_title': 'Maculopapular Rash',
#           'counts': [{'@group_id': 'E1',
#             '@subjects_affected': '1',
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '3',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '1',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '4'}]},
#          {'sub_title': 'Nail Disorder',
#           'counts': [{'@group_id': 'E1',
#             '@subjects_affected': '11',
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '10',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '1',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '4'}]},
#          {'sub_title': 'Night Sweats',
#           'counts': [{'@group_id': 'E1',
#             '@subjects_affected': '5',
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '3',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '4',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '4'}]},
#          {'sub_title': 'Pruritic Rash',
#           'counts': [{'@group_id': 'E1',
#             '@subjects_affected': '5',
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '4'}]},
#          {'sub_title': 'Pruritus',
#           'counts': [{'@group_id': 'E1',
#             '@subjects_affected': '16',
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '12',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '3',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '1',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '1',
#             '@subjects_at_risk': '4'}]},
#          {'sub_title': 'Rash',
#           'counts': [{'@group_id': 'E1',
#             '@subjects_affected': '21',
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '19',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '6',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '4'}]},
#          {'sub_title': 'Skin Carcinoma',
#           'counts': [{'@group_id': 'E1',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '1',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '1',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '4'}]},
#          {'sub_title': 'Skin Disorder',
#           'counts': [{'@group_id': 'E1',
#             '@subjects_affected': '3',
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '3',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '4'}]},
#          {'sub_title': 'Sweating',
#           'counts': [{'@group_id': 'E1',
#             '@subjects_affected': '1',
#             '@subjects_at_risk': '57'},
#            {'@group_id': 'E2',
#             '@subjects_affected': '3',
#             '@subjects_at_risk': '56'},
#            {'@group_id': 'E3',
#             '@subjects_affected': '7',
#             '@subjects_at_risk': '54'},
#            {'@group_id': 'E4',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '3'},
#            {'@group_id': 'E5',
#             '@subjects_affected': '0',
#             '@subjects_at_risk': '4'}]}]}}]}}},
#   'certain_agreements': {'pi_employee': 'Principal Investigators are NOT employed by the organization sponsoring the study.',
#    'restrictive_agreement': 'Pfizer has the right to review disclosures, requesting a delay of less than 60 days. Investigator will postpone single center publications until after disclosure of pooled data (all sites), less than 12 months from study completion/termination at all participating sites. Investigator may not disclose previously undisclosed confidential information other than study results.'},
#   'limitations_and_caveats': 'After the primary analysis was completed, efficacy data was no longer collected nor analyzed; Participants were followed for safety up to 6 months after the last dose of temsirolimus.',
#   'point_of_contact': {'name_or_title': 'Pfizer ClinicalTrials.gov Call Center',
#    'organization': 'Pfizer, Inc.',
#    'phone': '1-800-718-1021',
#    'email': 'ClinicalTrials.gov_Inquiries@pfizer.com'}}}
